# %% [markdown]
# # Source
#
#
#
# ### NAS
#
# https://arxiv.org/pdf/2502.03553
#
#
# ### Paramètre model
#
#
# https://chatgpt.com/share/6909153b-1c70-8013-8b6d-151bc8c5c976
#
#
#
# ### Doc Streamlit
#
#
# https://arnaudmiribel.github.io/streamlit-extras/extras/image_coordinates/
#
#
#
# https://kdd.org/exploration_files/7._CR._27._Techniques_for_Automated_Machine_Learning-2.pdf
#
#
#
# ## Repo util
#
#
# https://github.com/business-science/ai-data-science-team
