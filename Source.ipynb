# %% [markdown]
# # Source
#
#
# # Feature engineering
#
# https://arxiv.org/html/2503.14434v1
# https://github.com/nikhilsab/LLMFE
# https://www.microsoft.com/en-us/research/publication/neural-feature-search-a-neural-architecture-for-automated-feature-engineering/
#
#
# ### NAS
#
# https://arxiv.org/pdf/2502.03553
# https://arxiv.org/html/2508.13436v1
# https://www.oajaiml.com/uploads/archivepdf/134544176.pdf
# https://ceur-ws.org/Vol-3797/paper9.pdf
#
# https://towardsai.net/p/l/automl-nas-and-hyperparameter-tuning-navigating-the-landscape-of-machine-learning-automation
#
#
# ### Méta apprentissage
#
# https://lesdieuxducode.com/blog/2022/7/meta-apprentissage--apprendre-comment-apprendre
#
#
#
# ### Paramètre model
#
#
# https://chatgpt.com/share/6909153b-1c70-8013-8b6d-151bc8c5c976
#
#
#
# ### Doc Streamlit
#
#
# https://arnaudmiribel.github.io/streamlit-extras/extras/image_coordinates/
#
#
#
# https://kdd.org/exploration_files/7._CR._27._Techniques_for_Automated_Machine_Learning-2.pdf
#
#
#
# ## Repo util
#
#
# https://github.com/business-science/ai-data-science-team
#
#
#
#
# ## Source Test
#
# https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud/data
# https://www.kaggle.com/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset
# https://github.com/feedzai/bank-account-fraud
